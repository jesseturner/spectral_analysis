# %%
from readers import viirs_utils as v_utils
import os
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from datetime import datetime
import matplotlib.colors as mcolors
import numpy as np

# %%
today_date_str = datetime.now().strftime("%Y_%m_%d")

# %% [markdown]
# ## Plot Day/Night Band

# %%
dnb_dir = "data/dnb/" 
dnb_file = "GDNBO-SVDNB_j01_d20250312_t0639527_e0645327_b37894_c20250912025655090196_oebc_ops.h5"
file_path = os.path.join(dnb_dir, dnb_file)

# %%
v_utils.print_viirs_file_metadata(file_path)
v_utils.print_viirs_file_attrs(file_path, dataset="Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_0")
# Out:
# Group: All_Data
# Group: All_Data/VIIRS-DNB-GEO_All
# Dataset: All_Data/VIIRS-DNB-GEO_All/Height | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/Height_TC | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/Latitude | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/Latitude_TC | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/Longitude | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/Longitude_TC | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/LunarAzimuthAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/LunarZenithAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/MidTime | shape: (192,) | dtype: int64
# Dataset: All_Data/VIIRS-DNB-GEO_All/ModeGran | shape: (4,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/ModeScan | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/MoonIllumFraction | shape: (4,) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/MoonPhaseAngle | shape: (4,) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/NumberOfScans | shape: (4,) | dtype: int32
# Dataset: All_Data/VIIRS-DNB-GEO_All/PadByte1 | shape: (12,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/QF1_SCAN_VIIRSSDRGEO | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/QF2_SCAN_VIIRSSDRGEO | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/QF2_VIIRSSDRGEO | shape: (3072, 4064) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/QF2_VIIRSSDRGEO_TC | shape: (3072, 4064) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-GEO_All/SCAttitude | shape: (192, 3) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SCPosition | shape: (192, 3) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SCSolarAzimuthAngle | shape: (192,) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SCSolarZenithAngle | shape: (192,) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SCVelocity | shape: (192, 3) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SatelliteAzimuthAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SatelliteRange | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SatelliteZenithAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SolarAzimuthAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/SolarZenithAngle | shape: (3072, 4064) | dtype: float32
# Dataset: All_Data/VIIRS-DNB-GEO_All/StartTime | shape: (192,) | dtype: int64
# Group: All_Data/VIIRS-DNB-SDR_All
# Dataset: All_Data/VIIRS-DNB-SDR_All/ModeGran | shape: (4,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/ModeScan | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/NumberOfBadChecksums | shape: (192,) | dtype: int32
# Dataset: All_Data/VIIRS-DNB-SDR_All/NumberOfDiscardedPkts | shape: (192,) | dtype: int32
# Dataset: All_Data/VIIRS-DNB-SDR_All/NumberOfMissingPkts | shape: (192,) | dtype: int32
# Dataset: All_Data/VIIRS-DNB-SDR_All/NumberOfScans | shape: (4,) | dtype: int32
# Dataset: All_Data/VIIRS-DNB-SDR_All/PadByte1 | shape: (12,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/QF1_VIIRSDNBSDR | shape: (3072, 4064) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/QF2_SCAN_SDR | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/QF3_SCAN_RDR | shape: (192,) | dtype: uint8
# Dataset: All_Data/VIIRS-DNB-SDR_All/Radiance | shape: (3072, 4064) | dtype: float32
# Group: Data_Products
# Group: Data_Products/VIIRS-DNB-GEO
# Dataset: Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Aggr | shape: (30,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_0 | shape: (30,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_1 | shape: (30,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_2 | shape: (30,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_3 | shape: (30,) | dtype: object
# Group: Data_Products/VIIRS-DNB-SDR
# Dataset: Data_Products/VIIRS-DNB-SDR/VIIRS-DNB-SDR_Aggr | shape: (11,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-SDR/VIIRS-DNB-SDR_Gran_0 | shape: (11,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-SDR/VIIRS-DNB-SDR_Gran_1 | shape: (11,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-SDR/VIIRS-DNB-SDR_Gran_2 | shape: (11,) | dtype: object
# Dataset: Data_Products/VIIRS-DNB-SDR/VIIRS-DNB-SDR_Gran_3 | shape: (11,) | dtype: object
# Attributes of /Data_Products/VIIRS-DNB-GEO/VIIRS-DNB-GEO_Gran_0:
#   Ascending/Descending_Indicator: [[1]]
#   Beginning_Date: [[b'20250312']]
#   Beginning_Time: [[b'063952.714065Z']]
#   East_Bounding_Coordinate: [[-48.05269]]
#   Ending_Date: [[b'20250312']]
#   Ending_Time: [[b'064117.233697Z']]
#   G-Ring_Latitude: [[48.72373 ]
#  [51.308113]
#  [53.765804]
#  [52.415867]
#  [47.30984 ]
#  [45.14632 ]
#  [42.837307]
#  [47.486904]]
#   G-Ring_Longitude: [[-90.32962]
#  [-90.36544]
#  [-90.45842]
#  [-67.66729]
#  [-48.05269]
#  [-49.94273]
#  [-51.74163]
#  [-69.87171]]
#   N_Algorithm_Version: [[b'2.O.000.009']]
#   N_Anc_Filename: [[b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0655_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0656_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0657_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0658_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0659_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0660_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0686_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0687_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0688_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0689_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0690_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0691_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0692_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0718_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0719_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0720_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0721_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0722_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0723_1.O.0.0']
#  [b'Terrain-Eco-ANC-Tile_20030125000000Z_ee00000000000000Z_NA_NA_N0724_1.O.0.0']
#  [b'off_Planet-Eph-ANC_Static_JPL_000f_20200117_200001010000Z_20200101000000Z_ee00000000000000Z_np']
#  [b'off_USNO-PolarWander-UT1-ANC_Ser7_USNO_000f_20250307_202503070000Z_20250307000101Z_ee20250314120000Z_np']]
#   N_Aux_Filename: [[b'CMNGEO-PARAM-LUT_j01_20160331000000Z_20000101000000Z_ee00000000000000Z_PS-1-O-CCR-16-2859-v002-LE-PE_all-_all_all-_ops']
#  [b'CmnGeo-SAA-AC_j01_20151008180000Z_20020101010000Z_ee00000000000000Z_PS-1-O-NPP-1-LE-PE_all-_all_all-_ops']
#  [b'VIIRS-SDR-GEO-DNB-PARAM-V2-LUT_j01_20210607153404Z_20171118000000Z_ee00000000000000Z_PS-1-O-CCR-5511-009-LE-PE_all-_all_all-_ops']
#  [b'VIIRS-SDR-GEO-IMG-PARAM-V2-LUT_j01_20210514152759Z_20171118000000Z_ee00000000000000Z_PS-1-O-CCR-5511-009-LE-PE_all-_all_all-_ops']
#  [b'VIIRS-SDR-GEO-MOD-PARAM-V2-LUT_j01_20210514152539Z_20171118000000Z_ee00000000000000Z_PS-1-O-CCR-5511-009-LE-PE_all-_all_all-_ops']
#  [b'VIIRS-SDR-QA-V2-LUT_j01_20180502000000Z_20180319000000Z_ee00000000000000Z_PS-1-O-474-CCR-18-3966-V1-LE-PE_all-_all_all-_ops']]
#   N_Beginning_Orbit_Number: [[37894]]
#   N_Beginning_Time_IET: [[2120452829714065]]
#   N_Creation_Date: [[b'20250312']]
#   N_Creation_Time: [[b'073147.830000Z']]
#   N_Day_Night_Flag: [[b'Night']]
#   N_Ending_Time_IET: [[2120452914233697]]
#   N_Granule_ID: [[b'J01004224335944']]
#   N_Granule_Status: [[b'N/A']]
#   N_Granule_Version: [[b'A1']]
#   N_IDPS_Mode: [[b'ops']]
#   N_Input_Prod: [[b'SPACECRAFT-DIARY-RDR:J01004224335000:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224335200:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224335400:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224335600:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224335800:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224336000:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224336200:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224336400:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224336600:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224336800:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224337000:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224337200:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224337400:A1']
#  [b'SPACECRAFT-DIARY-RDR:J01004224337600:A1']
#  [b'VIIRS-SCIENCE-RDR:J01004224335091:A1']
#  [b'VIIRS-SCIENCE-RDR:J01004224335944:A1']
#  [b'VIIRS-SCIENCE-RDR:J01004224336798:A1']]
#   N_JPSS_Document_Ref: [[b'474-00448-02-06_JPSS-DD-Vol-II-Part-6_0200H.pdf']
#  [b'474-00448-02-06_JPSS-VIIRS-SDR-DD-Part-6_0200H_VIIRS-DNB-GEO-PP.xml']
#  [b'474-00448-03-06_JPSS-OAD-Vol-III-Part-6-VIIRS-RDR-SDR_-1.pdf']]
#   N_LEOA_Flag: [[b'Off']]
#   N_Nadir_Latitude_Max: [[52.37387]]
#   N_Nadir_Latitude_Min: [[47.54572]]
#   N_Nadir_Longitude_Max: [[-67.668945]]
#   N_Nadir_Longitude_Min: [[-69.83742]]
#   N_Number_Of_Scans: [[48]]
#   N_Primary_Label: [[b'Non-Primary']]
#   N_Quality_Summary_Names: [[b'Automatic Quality Flag']
#  [b'Percent Missing Data']
#  [b'Percent Out of Bounds']]
#   N_Quality_Summary_Values: [[0]
#  [0]
#  [0]]
#   N_Reference_ID: [[b'VIIRS-DNB-GEO:J01004224335944:A1']]
#   N_Software_Version: [[b'I2.3.12.00']]
#   N_Spacecraft_Maneuver: [[b'Normal Operations']]
#   North_Bounding_Coordinate: [[53.84648]]
#   South_Bounding_Coordinate: [[42.837307]]
#   West_Bounding_Coordinate: [[-90.45842]]

# %%
da = v_utils.open_dnb_radiance(file_path)
print(da)
# Out:
# --- Following error codes removed ---
# VDNE (32-bit): 65024 occurrences
# <xarray.DataArray 'Radiance' (y: 3056, x: 4064)> Size: 50MB
# array([[-1.5000000e-09,  1.4021640e-08,  1.9812914e-08, ...,
#          3.0349279e-09,  3.2330718e-09,  5.0676490e-09],
#        [-1.5000000e-09,  9.4457064e-09,  1.1520949e-08, ...,
#          2.5479159e-09,  3.6397751e-09,  5.8042100e-09],
#        [-1.5000000e-09,  7.5233260e-09,  6.2221366e-09, ...,
#          3.9099786e-09,  4.8137645e-09,  5.9191190e-09],
#        ...,
#        [-1.5000000e-09,  2.6718168e-09,  2.2437294e-09, ...,
#          2.8543998e-09,  2.6460067e-09,  3.0599088e-09],
#        [-1.5000000e-09,  5.1108819e-09,  3.4336356e-09, ...,
#          2.8013429e-09,  3.0047713e-09,  3.0814828e-09],
#        [-1.5000000e-09,  6.1209695e-09,  4.8136424e-09, ...,
#          2.8722944e-09,  2.8737785e-09,  2.4620095e-09]],
#       shape=(3056, 4064), dtype=float32)
# Coordinates:
#     Latitude   (y, x) float32 50MB 53.69 53.69 53.69 53.69 ... 27.39 27.38 27.36
#     Longitude  (y, x) float32 50MB -90.74 -90.73 -90.72 ... -53.9 -53.87 -53.84
# Dimensions without coordinates: y, x

# %%
projection=ccrs.PlateCarree(central_longitude=0)
fig,ax=plt.subplots(1, figsize=(12,12), subplot_kw={'projection': projection})

cmap = "binary_r"
pcm = plt.pcolormesh(da["Longitude"], da["Latitude"], da, cmap=cmap, shading="nearest", vmin=0.5e-9, vmax=9e-9)

clb = plt.colorbar(pcm, shrink=0.6, pad=0.02, ax=ax)
clb.ax.tick_params(labelsize=15)
clb.set_label('Radiance (W cm$^{-2}$ sr$^{-1}$)', fontsize=15)

pin_coords = None
if pin_coords:
    ax.plot(pin_coords[1], pin_coords[0], 
        marker='o', 
        markersize=12,
        markerfacecolor='red',
        markeredgecolor='white',
        markeredgewidth=1.5, 
        transform=ccrs.PlateCarree())

description = f"{dnb_file.split("_")[1]} {dnb_file.split("_")[2]} {dnb_file.split("_")[3]}"
plot_title = f"VIIRS Day/Night Band \n {description}"
ax.set_title(plot_title, fontsize=20, pad=10)

# ax.set_extent([-73, -57, 33, 46], crs=ccrs.PlateCarree())
ax.set_extent([-82, -56, 33, 49], crs=ccrs.PlateCarree())
ax.coastlines(resolution='50m', color='white', linewidth=1)

plt.savefig(f"plots/{today_date_str}_viirs_dnb.png", dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot VIIRS brightness temperature

# %%
viirs_dir = "data/viirs/"
viirs_file = "GMTCO-SVM12-SVM13-SVM15_j01_d20250312_t0639527_e0645327_b37894_c20251017052332443046_oebc_ops.h5"
file_path = os.path.join(viirs_dir, viirs_file)

da_sw = v_utils.open_viirs_brightness_temp(file_path, "M12")
da_lw = v_utils.open_viirs_brightness_temp(file_path, "M15")
da_btd = da_lw - da_sw
# Out:
# --- Following error codes removed ---
# VDNE (32-bit): 51200 occurrences
# Identified scale and offset as 0.002518045948818326, 203.0
# --- Following error codes removed ---
# VDNE (32-bit): 51200 occurrences
# Identified scale and offset as 0.004120438825339079, 111.0

# %%
def _print_value_at_point(da, pin_coords):
    dist = ((da['Latitude'] - pin_coords[0])**2 + (da['Longitude'] - pin_coords[1])**2)**0.5
    y_idx, x_idx = np.unravel_index(dist.argmin(), dist.shape)
    pin_value = da.isel(y=y_idx, x=x_idx).item()
    selected_lat = da['Latitude'].isel(y=y_idx, x=x_idx).item()
    selected_lon = da['Longitude'].isel(y=y_idx, x=x_idx).item()
    print(f"Value at ({selected_lat:.2f}, {selected_lon:.2f}): {pin_value:.2f} K")
    return

# %%
projection=ccrs.PlateCarree(central_longitude=0)
fig,ax=plt.subplots(1, figsize=(12,12), subplot_kw={'projection': projection})

cmap = mcolors.LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0, "#06BA63"), (0.5, "black"), (1, "white")]
)
norm = mcolors.TwoSlopeNorm(vmin=-6, vcenter=0, vmax=1.5)

pcm = plt.pcolormesh(da_btd["Longitude"], da_btd["Latitude"], da_btd, cmap=cmap, norm=norm, shading="nearest")

clb = plt.colorbar(pcm, shrink=0.6, pad=0.02, ax=ax)
clb.ax.tick_params(labelsize=15)
clb.set_label('(K)', fontsize=15)

pin_coords = None # (36, -72)
if pin_coords:
    ax.plot(pin_coords[1], pin_coords[0], 
        marker='o', 
        markersize=12,
        markerfacecolor='red',
        markeredgecolor='white',
        markeredgewidth=1.5, 
        transform=ccrs.PlateCarree())
    _print_value_at_point(da, pin_coords)

description = f"{viirs_file.split("_")[1]} {viirs_file.split("_")[2]} {viirs_file.split("_")[3]}"
plot_title = f"VIIRS M15 - M12 (10.76 μm - 3.7 μm) BTD \n {description}"
ax.set_title(plot_title, fontsize=20, pad=10)

ax.set_extent([-82, -56, 33, 49], crs=ccrs.PlateCarree())
ax.coastlines(resolution='50m', color='white', linewidth=1)

plt.savefig(f"plots/{today_date_str}_viirs_btd.png", dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot VIIRS spectral response function

# %% [markdown]
# * Using sensor response function file downloaded from https://ncc.nesdis.noaa.gov/VIIRS/VIIRSSpectralResponseFunctions.php

# %%
srf_file = "data/spectral_response_functions/NPP_VIIRS_NG_RSR_M12_filtered_Oct2011f_BA.dat"

# %%
srf = np.loadtxt(srf_file)
x = srf[:, 0]/1000
y = srf[:, 1]
band_str = f'VIIRS Band {srf_file.split("_")[7]}'

plt.plot(x, y, color='black', linewidth=1)
plt.xlabel('Wavelength (µm)')
plt.ylabel('Response')
plt.title(f'{band_str} \n NG Band-Averaged RSRs')

plt.savefig(f"plots/{today_date_str}_viirs_srf.png", dpi=200, bbox_inches='tight')
plt.show()
